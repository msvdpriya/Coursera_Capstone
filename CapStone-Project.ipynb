# %%
# Numpy and Pandas libraries were already imported at the beginning of this notebook.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
import folium # map rendering library

import requests # library to handle requests
import lxml.html as lh
import bs4 as bs
import urllib.request

# %% [markdown]
# 1. Downloading India States list with rating given to different mobile network operators within a state
# Rating of 1 corresponds to call droped or poor voice quality
# Rating of 3Satisfatory

# %%
df = pd.read_csv('CallQualityData.csv')
df.head(20)
# Out:
#     Operator In Out Travelling Network Type  Rating  Call Drop Category  \
# 0     Airtel            Indoor           4G       3        Satisfactory
# 1   Vodafone            Indoor           4G       1        Call Dropped
# 2     Airtel            Indoor           3G       1        Call Dropped
# 3     Airtel            Indoor      Unknown       1  Poor Voice Quality
# 4     Airtel            Indoor           4G       3        Satisfactory
# 5       Idea           Outdoor      Unknown       2  Poor Voice Quality
# 6     Airtel        Travelling           4G       3        Satisfactory
# 7     Airtel        Travelling           4G       3        Satisfactory
# 8     Airtel        Travelling           4G       5        Satisfactory
# 9     Airtel        Travelling           4G       4        Satisfactory
# 10    Airtel            Indoor           4G       5        Satisfactory
# 11      RJio            Indoor           4G       5        Satisfactory
# ...

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
